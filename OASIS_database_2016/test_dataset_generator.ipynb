# %%
from dataset_generators import generate_dataset

# %%
safe_men_df = generate_dataset(num_images=160,safe=True,sex='men')
safe_men_df.head()
# Out:
#     Unnamed: 0           Theme  Category                Source  \
# 327       I328         Fire 11         4               Pixabay
# 635       I636   Plane crash 1         2               Pixabay
# 699       I700      Sad pose 4         3               Pixabay
# 82         I83  Bloody knife 2         2  Flickr/Steven Depolo
# 737       I738          Shot 1         2               Pixabay
#
#      Valence_mean_men  Valence_SD_men  Valence_N_men  Arousal_mean_men  \
# 327          2.090909        1.177664             44          1.500000
# 635          2.866667        1.423823             45          2.410714
# 699          3.087719        0.987072             57          2.568627
# 82           2.396552        1.213082             58          2.069767
# 737          2.711111        1.254487             45          2.839286
#
#      Arousal_SD_men  Arousal_N_men  Valence_mean_women  Valence_SD_women  \
# 327        0.995604             58            5.021277          1.835512
# ...

# %%
import matplotlib.pyplot as plt 
#sample  = safe_men_df.sample(5)
for i,row in sample.iterrows():
    path = 'images/'+row['Theme'].strip() + '.jpg'
    #print(path)
    plt.figure()
    plt.imshow(plt.imread(path))
    print(row['Valence_mean_men'])
# Out:
# 5.46551724137931
# 4.0
# 2.78947368421053
# 4.19298245614035
# 4.37931034482759

# %%
safe_all_df = generate_dataset(num_images=160,safe=True)
safe_all_df.head()
# Out:
#     Unnamed: 0           Theme Category     Source  Valence_mean  Valence_SD  \
# 709       I710   Scared face 2   Person    Pixabay      3.774510    1.013834
# 87         I88    Bored pose 3   Person  Wikipedia      3.088235    0.857153
# 385       I386  Garbage dump 8    Scene    Pixabay      2.058824    1.124203
# 801       I802       Storage 3   Object    Pixabay      3.705882    1.139639
# 844       I845        Toilet 2   Object    Pixabay      3.648148    0.960090
#
#      Valence_N  Arousal_mean  Arousal_SD  Arousal_N Valence_mean_bin  \
# 709        102      3.198020    1.618764        101                1
# 87         102      2.712871    1.478761        101                1
# 385        102      3.148515    1.835136        101                1
# 801        102      2.554455    1.506488        101                1
# 844        108      2.288462    1.362986        104                1
#
#     Arousal_mean_bin
# 709                1
# 87                 1
# ...
